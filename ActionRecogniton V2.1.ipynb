# %% [markdown]
# 一、import some package

# %%
from __future__ import print_function
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import np_utils,plot_model
from keras.callbacks import ReduceLROnPlateau, CSVLogger, EarlyStopping,ModelCheckpoint
from keras.models import load_model
import matplotlib.pyplot as plt
import matplotlib.image as mping
import numpy as np
import resnet
import os
import pandas as pd
import random
from skimage import data, exposure, img_as_float
from skimage.transform import resize
from skimage.io import imread, imshow, imread_collection, concatenate_images
from sklearn.cross_validation import train_test_split

# %% [markdown]
# 二、读取图片进入X,Y

# %%
T=10
A=T
B=T
C=T
D=T
E=T
F=T
G=T
H=T
J=T
K=T
L=T
M=T
N=T
O=T
P=T

A=60
B=58
C=55
D=62
E=60
F=71
G=60
H=55
J=67
K=52
L=70
M=61
N=66
O=28
P=37
resize_rate=2
nb_classes = 15
dataset_num=A+B+C+D+E+F+G+H+J+K+L+M+N+O+P
input_img_rows=2448
input_img_cols=3264
img_rows=256
img_cols=256
img_channels=3
X=np.zeros([dataset_num,img_rows,img_cols,img_channels])
Y=np.zeros([dataset_num,nb_classes])

for i in range(A):
    imagepath=r'datasets2//A'+str(i+1)+r'.jpg'
    image_readin=mping.imread(imagepath)
    print(imagepath)
    image=image_readin[:,408:408+input_img_rows,:]
    image=resize(image, (img_rows, img_cols), mode='reflect')
    X[i,:,:,:]=image
    Y[i,0]=1
for i in range(B):
    imagepath=r'datasets2//B'+str(i+1)+r'.jpg'
    image_readin=mping.imread(imagepath)
    print(imagepath)
    image=image_readin[:,408:408+input_img_rows,:]
    image=resize(image, (img_rows, img_cols), mode='reflect')
    X[A+i,:,:,:]=image
    Y[A+i,1]=1
for i in range(C):
    imagepath=r'datasets2//C'+str(i+1)+r'.jpg'
    image_readin=mping.imread(imagepath)
    print(imagepath)
    image=image_readin[:,408:408+input_img_rows,:]
    image=resize(image, (img_rows, img_cols), mode='reflect')
    X[A+B+i,:,:,:]=image
    Y[A+B+i,1]=1
for i in range(D):
    imagepath=r'datasets2//D'+str(i+1)+r'.jpg'
    image_readin=mping.imread(imagepath)
    print(imagepath)
    image=image_readin[:,408:408+input_img_rows,:]
    image=resize(image, (img_rows, img_cols), mode='reflect')
    X[A+B+C+i,:,:,:]=image
    Y[A+B+C+i,1]=1
for i in range(E):
    imagepath=r'datasets2//E'+str(i+1)+r'.jpg'
    image_readin=mping.imread(imagepath)
    print(imagepath)
    image=image_readin[:,408:408+input_img_rows,:]
    image=resize(image, (img_rows, img_cols), mode='reflect')
    X[A+B+C+D+i,:,:,:]=image
    Y[A+B+C+D+i,1]=1
for i in range(F):
    imagepath=r'datasets2//F'+str(i+1)+r'.jpg'
    image_readin=mping.imread(imagepath)
    print(imagepath)
    image=image_readin[:,408:408+input_img_rows,:]
    image=resize(image, (img_rows, img_cols), mode='reflect')
    X[A+B+C+D+E+i,:,:,:]=image
    Y[A+B+C+D+E+i,1]=1
for i in range(G):
    imagepath=r'datasets2//G'+str(i+1)+r'.jpg'
    image_readin=mping.imread(imagepath)
    print(imagepath)
    image=image_readin[:,408:408+input_img_rows,:]
    image=resize(image, (img_rows, img_cols), mode='reflect')
    X[A+B+C+D+E+F+i,:,:,:]=image
    Y[A+B+C+D+E+F+i,1]=1
for i in range(H):
    imagepath=r'datasets2//H'+str(i+1)+r'.jpg'
    image_readin=mping.imread(imagepath)
    print(imagepath)
    image=image_readin[:,408:408+input_img_rows,:]
    image=resize(image, (img_rows, img_cols), mode='reflect')
    X[A+B+C+D+E+F+G+i,:,:,:]=image
    Y[A+B+C+D+E+F+G+i,1]=1
for i in range(J):
    imagepath=r'datasets2//J'+str(i+1)+r'.jpg'
    image_readin=mping.imread(imagepath)
    print(imagepath)
    image=image_readin[:,408:408+input_img_rows,:]
    image=resize(image, (img_rows, img_cols), mode='reflect')
    X[A+B+C+D+E+F+G+H+i,:,:,:]=image
    Y[A+B+C+D+E+F+G+H+i,1]=1
for i in range(K):
    imagepath=r'datasets2//K'+str(i+1)+r'.jpg'
    image_readin=mping.imread(imagepath)
    print(imagepath)
    image=image_readin[:,408:408+input_img_rows,:]
    image=resize(image, (img_rows, img_cols), mode='reflect')
    X[A+B+C+D+E+F+G+H+J+i,:,:,:]=image
    Y[A+B+C+D+E+F+G+H+J+i,1]=1
for i in range(L):
    imagepath=r'datasets2//L'+str(i+1)+r'.jpg'
    image_readin=mping.imread(imagepath)
    print(imagepath)
    image=image_readin[:,408:408+input_img_rows,:]
    image=resize(image, (img_rows, img_cols), mode='reflect')
    X[A+B+C+D+E+F+G+H+J+K+i,:,:,:]=image
    Y[A+B+C+D+E+F+G+H+J+K+i,1]=1
for i in range(M):
    imagepath=r'datasets2//M'+str(i+1)+r'.jpg'
    image_readin=mping.imread(imagepath)
    print(imagepath)
    image=image_readin[:,408:408+input_img_rows,:]
    image=resize(image, (img_rows, img_cols), mode='reflect')
    X[A+B+C+D+E+F+G+H+J+K+L+i,:,:,:]=image
    Y[A+B+C+D+E+F+G+H+J+K+L+i,1]=1
for i in range(N):
    imagepath=r'datasets2//N'+str(i+1)+r'.jpg'
    image_readin=mping.imread(imagepath)
    print(imagepath)
    image=image_readin[:,408:408+input_img_rows,:]
    image=resize(image, (img_rows, img_cols), mode='reflect')
    X[A+B+C+D+E+F+G+H+J+K+L+M+i,:,:,:]=image
    Y[A+B+C+D+E+F+G+H+J+K+L+M+i,1]=1
for i in range(O):
    imagepath=r'datasets2//O'+str(i+1)+r'.jpg'
    image_readin=mping.imread(imagepath)
    print(imagepath)
    image=image_readin[:,408:408+input_img_rows,:]
    image=resize(image, (img_rows, img_cols), mode='reflect')
    X[A+B+C+D+E+F+G+H+J+K+L+M+N+i,:,:,:]=image
    Y[A+B+C+D+E+F+G+H+J+K+L+M+N+i,1]=1
for i in range(P):
    imagepath=r'datasets2//P'+str(i+1)+r'.jpg'
    image_readin=mping.imread(imagepath)
    print(imagepath)
    image=image_readin[:,408:408+input_img_rows,:]
    image=resize(image, (img_rows, img_cols), mode='reflect')
    X[A+B+C+D+E+F+G+H+J+K+L+M+N+O+i,:,:,:]=image
    Y[A+B+C+D+E+F+G+H+J+K+L+M+N+O+i,1]=1
image_sample=X[2]
imshow(image_sample)
# Out:
# datasets2//A1.jpg
# datasets2//A2.jpg
# datasets2//A3.jpg
# datasets2//A4.jpg
# datasets2//A5.jpg
# datasets2//A6.jpg
# datasets2//A7.jpg
# datasets2//A8.jpg
# datasets2//A9.jpg
# datasets2//A10.jpg
# datasets2//A11.jpg
# datasets2//A12.jpg
# datasets2//A13.jpg
# datasets2//A14.jpg
# datasets2//A15.jpg
# datasets2//A16.jpg
# datasets2//A17.jpg
# datasets2//A18.jpg
# datasets2//A19.jpg
# datasets2//A20.jpg
# datasets2//A21.jpg
# datasets2//A22.jpg
# datasets2//A23.jpg
# datasets2//A24.jpg
# datasets2//A25.jpg
# datasets2//A26.jpg
# datasets2//A27.jpg
# datasets2//A28.jpg
# datasets2//A29.jpg
# datasets2//A30.jpg
# datasets2//A31.jpg
# datasets2//A32.jpg
# datasets2//A33.jpg
# datasets2//A34.jpg
# datasets2//A35.jpg
# datasets2//A36.jpg
# datasets2//A37.jpg
# datasets2//A38.jpg
# datasets2//A39.jpg
# datasets2//A40.jpg
# datasets2//A41.jpg
# datasets2//A42.jpg
# datasets2//A43.jpg
# datasets2//A44.jpg
# datasets2//A45.jpg
# datasets2//A46.jpg
# datasets2//A47.jpg
# datasets2//A48.jpg
# datasets2//A49.jpg
# datasets2//A50.jpg
# datasets2//A51.jpg
# datasets2//A52.jpg
# datasets2//A53.jpg
# datasets2//A54.jpg
# datasets2//A55.jpg
# datasets2//A56.jpg
# datasets2//A57.jpg
# datasets2//A58.jpg
# datasets2//A59.jpg
# datasets2//A60.jpg
# datasets2//B1.jpg
# datasets2//B2.jpg
# datasets2//B3.jpg
# datasets2//B4.jpg
# datasets2//B5.jpg
# datasets2//B6.jpg
# datasets2//B7.jpg
# datasets2//B8.jpg
# datasets2//B9.jpg
# datasets2//B10.jpg
# datasets2//B11.jpg
# datasets2//B12.jpg
# datasets2//B13.jpg
# datasets2//B14.jpg
# datasets2//B15.jpg
# datasets2//B16.jpg
# datasets2//B17.jpg
# datasets2//B18.jpg
# datasets2//B19.jpg
# datasets2//B20.jpg
# datasets2//B21.jpg
# datasets2//B22.jpg
# datasets2//B23.jpg
# datasets2//B24.jpg
# datasets2//B25.jpg
# datasets2//B26.jpg
# datasets2//B27.jpg
# datasets2//B28.jpg
# datasets2//B29.jpg
# datasets2//B30.jpg
# datasets2//B31.jpg
# datasets2//B32.jpg
# datasets2//B33.jpg
# datasets2//B34.jpg
# datasets2//B35.jpg
# datasets2//B36.jpg
# datasets2//B37.jpg
# datasets2//B38.jpg
# datasets2//B39.jpg
# datasets2//B40.jpg
# datasets2//B41.jpg
# datasets2//B42.jpg
# datasets2//B43.jpg
# datasets2//B44.jpg
# datasets2//B45.jpg
# datasets2//B46.jpg
# datasets2//B47.jpg
# datasets2//B48.jpg
# datasets2//B49.jpg
# datasets2//B50.jpg
# datasets2//B51.jpg
# datasets2//B52.jpg
# datasets2//B53.jpg
# datasets2//B54.jpg
# datasets2//B55.jpg
# datasets2//B56.jpg
# datasets2//B57.jpg
# datasets2//B58.jpg
# datasets2//C1.jpg
# datasets2//C2.jpg
# datasets2//C3.jpg
# datasets2//C4.jpg
# datasets2//C5.jpg
# datasets2//C6.jpg
# datasets2//C7.jpg
# datasets2//C8.jpg
# datasets2//C9.jpg
# datasets2//C10.jpg
# datasets2//C11.jpg
# datasets2//C12.jpg
# datasets2//C13.jpg
# datasets2//C14.jpg
# datasets2//C15.jpg
# datasets2//C16.jpg
# datasets2//C17.jpg
# datasets2//C18.jpg
# datasets2//C19.jpg
# datasets2//C20.jpg
# datasets2//C21.jpg
# datasets2//C22.jpg
# datasets2//C23.jpg
# datasets2//C24.jpg
# datasets2//C25.jpg
# datasets2//C26.jpg
# datasets2//C27.jpg
# datasets2//C28.jpg
# datasets2//C29.jpg
# datasets2//C30.jpg
# datasets2//C31.jpg
# datasets2//C32.jpg
# datasets2//C33.jpg
# datasets2//C34.jpg
# datasets2//C35.jpg
# datasets2//C36.jpg
# datasets2//C37.jpg
# datasets2//C38.jpg
# datasets2//C39.jpg
# datasets2//C40.jpg
# datasets2//C41.jpg
# datasets2//C42.jpg
# datasets2//C43.jpg
# datasets2//C44.jpg
# datasets2//C45.jpg
# datasets2//C46.jpg
# datasets2//C47.jpg
# datasets2//C48.jpg
# datasets2//C49.jpg
# datasets2//C50.jpg
# datasets2//C51.jpg
# datasets2//C52.jpg
# datasets2//C53.jpg
# datasets2//C54.jpg
# datasets2//C55.jpg
# datasets2//D1.jpg
# datasets2//D2.jpg
# datasets2//D3.jpg
# datasets2//D4.jpg
# datasets2//D5.jpg
# datasets2//D6.jpg
# datasets2//D7.jpg
# datasets2//D8.jpg
# datasets2//D9.jpg
# datasets2//D10.jpg
# datasets2//D11.jpg
# datasets2//D12.jpg
# datasets2//D13.jpg
# datasets2//D14.jpg
# datasets2//D15.jpg
# datasets2//D16.jpg
# datasets2//D17.jpg
# datasets2//D18.jpg
# datasets2//D19.jpg
# datasets2//D20.jpg
# datasets2//D21.jpg
# datasets2//D22.jpg
# datasets2//D23.jpg
# datasets2//D24.jpg
# datasets2//D25.jpg
# datasets2//D26.jpg
# datasets2//D27.jpg
# datasets2//D28.jpg
# datasets2//D29.jpg
# datasets2//D30.jpg
# datasets2//D31.jpg
# datasets2//D32.jpg
# datasets2//D33.jpg
# datasets2//D34.jpg
# datasets2//D35.jpg
# datasets2//D36.jpg
# datasets2//D37.jpg
# datasets2//D38.jpg
# datasets2//D39.jpg
# datasets2//D40.jpg
# datasets2//D41.jpg
# datasets2//D42.jpg
# datasets2//D43.jpg
# datasets2//D44.jpg
# datasets2//D45.jpg
# datasets2//D46.jpg
# datasets2//D47.jpg
# datasets2//D48.jpg
# datasets2//D49.jpg
# datasets2//D50.jpg
# datasets2//D51.jpg
# datasets2//D52.jpg
# datasets2//D53.jpg
# datasets2//D54.jpg
# datasets2//D55.jpg
# datasets2//D56.jpg
# datasets2//D57.jpg
# datasets2//D58.jpg
# datasets2//D59.jpg
# datasets2//D60.jpg
# datasets2//D61.jpg
# datasets2//D62.jpg
# datasets2//E1.jpg
# datasets2//E2.jpg
# datasets2//E3.jpg
# datasets2//E4.jpg
# datasets2//E5.jpg
# datasets2//E6.jpg
# datasets2//E7.jpg
# datasets2//E8.jpg
# datasets2//E9.jpg
# datasets2//E10.jpg
# datasets2//E11.jpg
# datasets2//E12.jpg
# datasets2//E13.jpg
# datasets2//E14.jpg
# datasets2//E15.jpg
# datasets2//E16.jpg
# datasets2//E17.jpg
# datasets2//E18.jpg
# datasets2//E19.jpg
# datasets2//E20.jpg
# datasets2//E21.jpg
# datasets2//E22.jpg
# datasets2//E23.jpg
# datasets2//E24.jpg
# datasets2//E25.jpg
# datasets2//E26.jpg
# datasets2//E27.jpg
# datasets2//E28.jpg
# datasets2//E29.jpg
# datasets2//E30.jpg
# datasets2//E31.jpg
# datasets2//E32.jpg
# datasets2//E33.jpg
# datasets2//E34.jpg
# datasets2//E35.jpg
# datasets2//E36.jpg
# datasets2//E37.jpg
# datasets2//E38.jpg
# datasets2//E39.jpg
# datasets2//E40.jpg
# datasets2//E41.jpg
# datasets2//E42.jpg
# datasets2//E43.jpg
# datasets2//E44.jpg
# datasets2//E45.jpg
# datasets2//E46.jpg
# datasets2//E47.jpg
# datasets2//E48.jpg
# datasets2//E49.jpg
# datasets2//E50.jpg
# datasets2//E51.jpg
# datasets2//E52.jpg
# datasets2//E53.jpg
# datasets2//E54.jpg
# datasets2//E55.jpg
# datasets2//E56.jpg
# datasets2//E57.jpg
# datasets2//E58.jpg
# datasets2//E59.jpg
# datasets2//E60.jpg
# datasets2//F1.jpg
# datasets2//F2.jpg
# datasets2//F3.jpg
# datasets2//F4.jpg
# datasets2//F5.jpg
# datasets2//F6.jpg
# datasets2//F7.jpg
# datasets2//F8.jpg
# datasets2//F9.jpg
# datasets2//F10.jpg
# datasets2//F11.jpg
# datasets2//F12.jpg
# datasets2//F13.jpg
# datasets2//F14.jpg
# datasets2//F15.jpg
# datasets2//F16.jpg
# datasets2//F17.jpg
# datasets2//F18.jpg
# datasets2//F19.jpg
# datasets2//F20.jpg
# datasets2//F21.jpg
# datasets2//F22.jpg
# datasets2//F23.jpg
# datasets2//F24.jpg
# datasets2//F25.jpg
# datasets2//F26.jpg
# datasets2//F27.jpg
# datasets2//F28.jpg
# datasets2//F29.jpg
# datasets2//F30.jpg
# datasets2//F31.jpg
# datasets2//F32.jpg
# datasets2//F33.jpg
# datasets2//F34.jpg
# datasets2//F35.jpg
# datasets2//F36.jpg
# datasets2//F37.jpg
# datasets2//F38.jpg
# datasets2//F39.jpg
# datasets2//F40.jpg
# datasets2//F41.jpg
# datasets2//F42.jpg
# datasets2//F43.jpg
# datasets2//F44.jpg
# datasets2//F45.jpg
# datasets2//F46.jpg
# datasets2//F47.jpg
# datasets2//F48.jpg
# datasets2//F49.jpg
# datasets2//F50.jpg
# datasets2//F51.jpg
# datasets2//F52.jpg
# datasets2//F53.jpg
# datasets2//F54.jpg
# datasets2//F55.jpg
# datasets2//F56.jpg
# datasets2//F57.jpg
# datasets2//F58.jpg
# datasets2//F59.jpg
# datasets2//F60.jpg
# datasets2//F61.jpg
# datasets2//F62.jpg
# datasets2//F63.jpg
# datasets2//F64.jpg
# datasets2//F65.jpg
# datasets2//F66.jpg
# datasets2//F67.jpg
# datasets2//F68.jpg
# datasets2//F69.jpg
# datasets2//F70.jpg
# datasets2//F71.jpg
# datasets2//G1.jpg
# datasets2//G2.jpg
# datasets2//G3.jpg
# datasets2//G4.jpg
# datasets2//G5.jpg
# datasets2//G6.jpg
# datasets2//G7.jpg
# datasets2//G8.jpg
# datasets2//G9.jpg
# datasets2//G10.jpg
# datasets2//G11.jpg
# datasets2//G12.jpg
# datasets2//G13.jpg
# datasets2//G14.jpg
# datasets2//G15.jpg
# datasets2//G16.jpg
# datasets2//G17.jpg
# datasets2//G18.jpg
# datasets2//G19.jpg
# datasets2//G20.jpg
# datasets2//G21.jpg
# datasets2//G22.jpg
# datasets2//G23.jpg
# datasets2//G24.jpg
# datasets2//G25.jpg
# datasets2//G26.jpg
# datasets2//G27.jpg
# datasets2//G28.jpg
# datasets2//G29.jpg
# datasets2//G30.jpg
# datasets2//G31.jpg
# datasets2//G32.jpg
# datasets2//G33.jpg
# datasets2//G34.jpg
# datasets2//G35.jpg
# datasets2//G36.jpg
# datasets2//G37.jpg
# datasets2//G38.jpg
# datasets2//G39.jpg
# datasets2//G40.jpg
# datasets2//G41.jpg
# datasets2//G42.jpg
# datasets2//G43.jpg
# datasets2//G44.jpg
# datasets2//G45.jpg
# datasets2//G46.jpg
# datasets2//G47.jpg
# datasets2//G48.jpg
# datasets2//G49.jpg
# datasets2//G50.jpg
# datasets2//G51.jpg
# datasets2//G52.jpg
# datasets2//G53.jpg
# datasets2//G54.jpg
# datasets2//G55.jpg
# datasets2//G56.jpg
# datasets2//G57.jpg
# datasets2//G58.jpg
# datasets2//G59.jpg
# datasets2//G60.jpg
# datasets2//H1.jpg
# datasets2//H2.jpg
# datasets2//H3.jpg
# datasets2//H4.jpg
# datasets2//H5.jpg
# datasets2//H6.jpg
# datasets2//H7.jpg
# datasets2//H8.jpg
# datasets2//H9.jpg
# datasets2//H10.jpg
# datasets2//H11.jpg
# datasets2//H12.jpg
# datasets2//H13.jpg
# datasets2//H14.jpg
# datasets2//H15.jpg
# datasets2//H16.jpg
# datasets2//H17.jpg
# datasets2//H18.jpg
# datasets2//H19.jpg
# datasets2//H20.jpg
# datasets2//H21.jpg
# datasets2//H22.jpg
# datasets2//H23.jpg
# datasets2//H24.jpg
# datasets2//H25.jpg
# datasets2//H26.jpg
# datasets2//H27.jpg
# datasets2//H28.jpg
# datasets2//H29.jpg
# datasets2//H30.jpg
# datasets2//H31.jpg
# datasets2//H32.jpg
# datasets2//H33.jpg
# datasets2//H34.jpg
# datasets2//H35.jpg
# datasets2//H36.jpg
# datasets2//H37.jpg
# datasets2//H38.jpg
# datasets2//H39.jpg
# datasets2//H40.jpg
# datasets2//H41.jpg
# datasets2//H42.jpg
# datasets2//H43.jpg
# datasets2//H44.jpg
# datasets2//H45.jpg
# datasets2//H46.jpg
# datasets2//H47.jpg
# datasets2//H48.jpg
# datasets2//H49.jpg
# datasets2//H50.jpg
# datasets2//H51.jpg
# datasets2//H52.jpg
# datasets2//H53.jpg
# datasets2//H54.jpg
# datasets2//H55.jpg
# datasets2//J1.jpg
# datasets2//J2.jpg
# datasets2//J3.jpg
# datasets2//J4.jpg
# datasets2//J5.jpg
# datasets2//J6.jpg
# datasets2//J7.jpg
# datasets2//J8.jpg
# datasets2//J9.jpg
# datasets2//J10.jpg
# datasets2//J11.jpg
# datasets2//J12.jpg
# datasets2//J13.jpg
# datasets2//J14.jpg
# datasets2//J15.jpg
# datasets2//J16.jpg
# datasets2//J17.jpg
# datasets2//J18.jpg
# datasets2//J19.jpg
# datasets2//J20.jpg
# datasets2//J21.jpg
# datasets2//J22.jpg
# datasets2//J23.jpg
# datasets2//J24.jpg
# datasets2//J25.jpg
# datasets2//J26.jpg
# datasets2//J27.jpg
# datasets2//J28.jpg
# datasets2//J29.jpg
# datasets2//J30.jpg
# datasets2//J31.jpg
# datasets2//J32.jpg
# datasets2//J33.jpg
# datasets2//J34.jpg
# datasets2//J35.jpg
# datasets2//J36.jpg
# datasets2//J37.jpg
# datasets2//J38.jpg
# datasets2//J39.jpg
# datasets2//J40.jpg
# datasets2//J41.jpg
# datasets2//J42.jpg
# datasets2//J43.jpg
# datasets2//J44.jpg
# datasets2//J45.jpg
# datasets2//J46.jpg
# datasets2//J47.jpg
# datasets2//J48.jpg
# datasets2//J49.jpg
# datasets2//J50.jpg
# datasets2//J51.jpg
# datasets2//J52.jpg
# datasets2//J53.jpg
# datasets2//J54.jpg
# datasets2//J55.jpg
# datasets2//J56.jpg
# datasets2//J57.jpg
# datasets2//J58.jpg
# datasets2//J59.jpg
# datasets2//J60.jpg
# datasets2//J61.jpg
# datasets2//J62.jpg
# datasets2//J63.jpg
# datasets2//J64.jpg
# datasets2//J65.jpg
# datasets2//J66.jpg
# datasets2//J67.jpg
# datasets2//K1.jpg
# datasets2//K2.jpg
# datasets2//K3.jpg
# datasets2//K4.jpg
# datasets2//K5.jpg
# datasets2//K6.jpg
# datasets2//K7.jpg
# datasets2//K8.jpg
# datasets2//K9.jpg
# datasets2//K10.jpg
# datasets2//K11.jpg
# datasets2//K12.jpg
# datasets2//K13.jpg
# datasets2//K14.jpg
# datasets2//K15.jpg
# datasets2//K16.jpg
# datasets2//K17.jpg
# datasets2//K18.jpg
# datasets2//K19.jpg
# datasets2//K20.jpg
# datasets2//K21.jpg
# datasets2//K22.jpg
# datasets2//K23.jpg
# datasets2//K24.jpg
# datasets2//K25.jpg
# datasets2//K26.jpg
# datasets2//K27.jpg
# datasets2//K28.jpg
# datasets2//K29.jpg
# datasets2//K30.jpg
# datasets2//K31.jpg
# datasets2//K32.jpg
# datasets2//K33.jpg
# datasets2//K34.jpg
# datasets2//K35.jpg
# datasets2//K36.jpg
# datasets2//K37.jpg
# datasets2//K38.jpg
# datasets2//K39.jpg
# datasets2//K40.jpg
# datasets2//K41.jpg
# datasets2//K42.jpg
# datasets2//K43.jpg
# datasets2//K44.jpg
# datasets2//K45.jpg
# datasets2//K46.jpg
# datasets2//K47.jpg
# datasets2//K48.jpg
# datasets2//K49.jpg
# datasets2//K50.jpg
# datasets2//K51.jpg
# datasets2//K52.jpg
# datasets2//L1.jpg
# datasets2//L2.jpg
# datasets2//L3.jpg
# datasets2//L4.jpg
# datasets2//L5.jpg
# datasets2//L6.jpg
# datasets2//L7.jpg
# datasets2//L8.jpg
# datasets2//L9.jpg
# datasets2//L10.jpg
# datasets2//L11.jpg
# datasets2//L12.jpg
# datasets2//L13.jpg
# datasets2//L14.jpg
# datasets2//L15.jpg
# datasets2//L16.jpg
# datasets2//L17.jpg
# datasets2//L18.jpg
# datasets2//L19.jpg
# datasets2//L20.jpg
# datasets2//L21.jpg
# datasets2//L22.jpg
# datasets2//L23.jpg
# datasets2//L24.jpg
# datasets2//L25.jpg
# datasets2//L26.jpg
# datasets2//L27.jpg
# datasets2//L28.jpg
# datasets2//L29.jpg
# datasets2//L30.jpg
# datasets2//L31.jpg
# datasets2//L32.jpg
# datasets2//L33.jpg
# datasets2//L34.jpg
# datasets2//L35.jpg
# datasets2//L36.jpg
# datasets2//L37.jpg
# datasets2//L38.jpg
# datasets2//L39.jpg
# datasets2//L40.jpg
# datasets2//L41.jpg
# datasets2//L42.jpg
# datasets2//L43.jpg
# datasets2//L44.jpg
# datasets2//L45.jpg
# datasets2//L46.jpg
# datasets2//L47.jpg
# datasets2//L48.jpg
# datasets2//L49.jpg
# datasets2//L50.jpg
# datasets2//L51.jpg
# datasets2//L52.jpg
# datasets2//L53.jpg
# datasets2//L54.jpg
# datasets2//L55.jpg
# datasets2//L56.jpg
# datasets2//L57.jpg
# datasets2//L58.jpg
# datasets2//L59.jpg
# datasets2//L60.jpg
# datasets2//L61.jpg
# datasets2//L62.jpg
# datasets2//L63.jpg
# datasets2//L64.jpg
# datasets2//L65.jpg
# datasets2//L66.jpg
# datasets2//L67.jpg
# datasets2//L68.jpg
# datasets2//L69.jpg
# datasets2//L70.jpg
# datasets2//M1.jpg
# datasets2//M2.jpg
# datasets2//M3.jpg
# datasets2//M4.jpg
# datasets2//M5.jpg
# datasets2//M6.jpg
# datasets2//M7.jpg
# datasets2//M8.jpg
# datasets2//M9.jpg
# datasets2//M10.jpg
# datasets2//M11.jpg
# datasets2//M12.jpg
# datasets2//M13.jpg
# datasets2//M14.jpg
# datasets2//M15.jpg
# datasets2//M16.jpg
# datasets2//M17.jpg
# datasets2//M18.jpg
# datasets2//M19.jpg
# datasets2//M20.jpg
# datasets2//M21.jpg
# datasets2//M22.jpg
# datasets2//M23.jpg
# datasets2//M24.jpg
# datasets2//M25.jpg
# datasets2//M26.jpg
# datasets2//M27.jpg
# datasets2//M28.jpg
# datasets2//M29.jpg
# datasets2//M30.jpg
# datasets2//M31.jpg
# datasets2//M32.jpg
# datasets2//M33.jpg
# datasets2//M34.jpg
# datasets2//M35.jpg
# datasets2//M36.jpg
# datasets2//M37.jpg
# datasets2//M38.jpg
# datasets2//M39.jpg
# datasets2//M40.jpg
# datasets2//M41.jpg
# datasets2//M42.jpg
# datasets2//M43.jpg
# datasets2//M44.jpg
# datasets2//M45.jpg
# datasets2//M46.jpg
# datasets2//M47.jpg
# datasets2//M48.jpg
# datasets2//M49.jpg
# datasets2//M50.jpg
# datasets2//M51.jpg
# datasets2//M52.jpg
# datasets2//M53.jpg
# datasets2//M54.jpg
# datasets2//M55.jpg
# datasets2//M56.jpg
# datasets2//M57.jpg
# datasets2//M58.jpg
# datasets2//M59.jpg
# datasets2//M60.jpg
# datasets2//M61.jpg
# datasets2//N1.jpg
# datasets2//N2.jpg
# datasets2//N3.jpg
# datasets2//N4.jpg
# datasets2//N5.jpg
# datasets2//N6.jpg
# datasets2//N7.jpg
# datasets2//N8.jpg
# datasets2//N9.jpg
# datasets2//N10.jpg
# datasets2//N11.jpg
# datasets2//N12.jpg
# datasets2//N13.jpg
# datasets2//N14.jpg
# datasets2//N15.jpg
# datasets2//N16.jpg
# datasets2//N17.jpg
# datasets2//N18.jpg
# datasets2//N19.jpg
# datasets2//N20.jpg
# datasets2//N21.jpg
# datasets2//N22.jpg
# datasets2//N23.jpg
# datasets2//N24.jpg
# datasets2//N25.jpg
# datasets2//N26.jpg
# datasets2//N27.jpg
# datasets2//N28.jpg
# datasets2//N29.jpg
# datasets2//N30.jpg
# datasets2//N31.jpg
# datasets2//N32.jpg
# datasets2//N33.jpg
# datasets2//N34.jpg
# datasets2//N35.jpg
# datasets2//N36.jpg
# datasets2//N37.jpg
# datasets2//N38.jpg
# datasets2//N39.jpg
# datasets2//N40.jpg
# datasets2//N41.jpg
# datasets2//N42.jpg
# datasets2//N43.jpg
# datasets2//N44.jpg
# datasets2//N45.jpg
# datasets2//N46.jpg
# datasets2//N47.jpg
# datasets2//N48.jpg
# datasets2//N49.jpg
# datasets2//N50.jpg
# datasets2//N51.jpg
# datasets2//N52.jpg
# datasets2//N53.jpg
# datasets2//N54.jpg
# datasets2//N55.jpg
# datasets2//N56.jpg
# datasets2//N57.jpg
# datasets2//N58.jpg
# datasets2//N59.jpg
# datasets2//N60.jpg
# datasets2//N61.jpg
# datasets2//N62.jpg
# datasets2//N63.jpg
# datasets2//N64.jpg
# datasets2//N65.jpg
# datasets2//N66.jpg
# datasets2//O1.jpg
# datasets2//O2.jpg
# datasets2//O3.jpg
# datasets2//O4.jpg
# datasets2//O5.jpg
# datasets2//O6.jpg
# datasets2//O7.jpg
# datasets2//O8.jpg
# datasets2//O9.jpg
# datasets2//O10.jpg
# datasets2//O11.jpg
# datasets2//O12.jpg
# datasets2//O13.jpg
# datasets2//O14.jpg
# datasets2//O15.jpg
# datasets2//O16.jpg
# datasets2//O17.jpg
# datasets2//O18.jpg
# datasets2//O19.jpg
# datasets2//O20.jpg
# datasets2//O21.jpg
# datasets2//O22.jpg
# datasets2//O23.jpg
# datasets2//O24.jpg
# datasets2//O25.jpg
# datasets2//O26.jpg
# datasets2//O27.jpg
# datasets2//O28.jpg
# datasets2//P1.jpg
# datasets2//P2.jpg
# datasets2//P3.jpg
# datasets2//P4.jpg
# datasets2//P5.jpg
# datasets2//P6.jpg
# datasets2//P7.jpg
# datasets2//P8.jpg
# datasets2//P9.jpg
# datasets2//P10.jpg
# datasets2//P11.jpg
# datasets2//P12.jpg
# datasets2//P13.jpg
# datasets2//P14.jpg
# datasets2//P15.jpg
# datasets2//P16.jpg
# datasets2//P17.jpg
# datasets2//P18.jpg
# datasets2//P19.jpg
# datasets2//P20.jpg
# datasets2//P21.jpg
# datasets2//P22.jpg
# datasets2//P23.jpg
# datasets2//P24.jpg
# datasets2//P25.jpg
# datasets2//P26.jpg
# datasets2//P27.jpg
# datasets2//P28.jpg
# datasets2//P29.jpg
# datasets2//P30.jpg
# datasets2//P31.jpg
# datasets2//P32.jpg
# datasets2//P33.jpg
# datasets2//P34.jpg
# datasets2//P35.jpg
# datasets2//P36.jpg
# datasets2//P37.jpg
# C:\ProgramData\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %% [markdown]
# 三、网络的一些超参数

# %%
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1), cooldown=0, patience=7, min_lr=0.5e-6)
early_stopper = EarlyStopping(min_delta=0.0005, patience=40)
csv_logger = CSVLogger('imagemodel2.1.csv')
checkpointer = ModelCheckpoint('imagemodel2.1.h5', verbose=1, save_best_only=True)
batch_size = 10
nb_epoch = 300
data_augmentation = False

# %% [markdown]
# 四、预处理，白化

# %%
X=X.astype('float32')
mean_X=np.mean(X,axis=0)
X -= mean_X  #白化，X减去所有数据的均值
X /=128 #这样X大概就是在-1~1之间的分布了

# %% [markdown]
# 五、搭建网络模型，编译

# %%
model = resnet.ResnetBuilder.build_resnet_34((img_channels, img_rows, img_cols), nb_classes)
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
model.summary()
#plot_model(model, to_file='model V2.0.png')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 64)   36928       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 64, 64)   0           max_pooling2d_1[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 64)   256         add_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 64)   36928       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 64)   0           add_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 64)   256         add_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 64)   36928       activation_6[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 64, 64)   0           add_2[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 64)   256         add_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 64, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 128)  73856       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 128)  8320        add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 128)  147584      activation_8[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 32, 32, 128)  0           conv2d_10[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 128)  512         add_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 32, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 128)  147584      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 128)  147584      activation_10[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 32, 32, 128)  0           add_4[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 128)  512         add_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 32, 32, 128)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 32, 32, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 128)  147584      activation_12[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 32, 32, 128)  0           add_5[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 32, 32, 128)  512         add_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 32, 32, 128)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 128)  147584      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 32, 128)  512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 32, 32, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 32, 32, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 32, 32, 128)  0           add_6[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 32, 32, 128)  512         add_7[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 32, 32, 128)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 256)  295168      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 16, 16, 256)  1024        conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 16, 16, 256)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 16, 16, 256)  33024       add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 256)  590080      activation_16[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 16, 16, 256)  0           conv2d_19[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 16, 256)  1024        add_8[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 16, 16, 256)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 16, 16, 256)  590080      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 16, 16, 256)  1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 16, 16, 256)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 16, 16, 256)  590080      activation_18[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 16, 16, 256)  0           add_8[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 16, 16, 256)  1024        add_9[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 16, 16, 256)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 16, 16, 256)  590080      activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 16, 16, 256)  1024        conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 16, 16, 256)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 16, 16, 256)  590080      activation_20[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 16, 16, 256)  0           add_9[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 16, 16, 256)  1024        add_10[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 16, 16, 256)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 16, 16, 256)  590080      activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 16, 16, 256)  1024        conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 16, 16, 256)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 16, 16, 256)  590080      activation_22[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 16, 16, 256)  0           add_10[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 16, 16, 256)  1024        add_11[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 16, 16, 256)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 16, 16, 256)  590080      activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16, 16, 256)  1024        conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 16, 16, 256)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 256)  590080      activation_24[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 16, 16, 256)  0           add_11[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 16, 16, 256)  1024        add_12[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 16, 16, 256)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 16, 16, 256)  590080      activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 16, 16, 256)  1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 16, 16, 256)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 16, 16, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 16, 16, 256)  0           add_12[0][0]
#                                                                  conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 16, 16, 256)  1024        add_13[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 16, 16, 256)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 8, 8, 512)    1180160     activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 8, 8, 512)    2048        conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 8, 8, 512)    0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 8, 8, 512)    131584      add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 8, 8, 512)    2359808     activation_28[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 8, 8, 512)    0           conv2d_32[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 8, 8, 512)    2048        add_14[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 8, 8, 512)    0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 8, 8, 512)    2359808     activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 8, 8, 512)    2048        conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 8, 8, 512)    0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 8, 8, 512)    2359808     activation_30[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 8, 8, 512)    0           add_14[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 8, 8, 512)    2048        add_15[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 8, 8, 512)    0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 8, 8, 512)    2359808     activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 8, 8, 512)    2048        conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 8, 8, 512)    0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 8, 512)    2359808     activation_32[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 8, 8, 512)    0           add_15[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 8, 8, 512)    2048        add_16[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 8, 8, 512)    0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 512)    0           activation_33[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 15)           7695        flatten_1[0][0]
# ==================================================================================================
# Total params: 21,314,319
# Trainable params: 21,299,087
# Non-trainable params: 15,232
# __________________________________________________________________________________________________

# %% [markdown]
# 六、分割X={X_train,X_val}  Y={Y_train,Y_val}

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.9, random_state=42)
print("X_train.shape=",X_train.shape)
print("Y_train.shape=",Y_train.shape)
print("X_val.shape=",X_val.shape)
print("Y_val.shape=",Y_val.shape)
# Out:
# X_train.shape= (86, 256, 256, 3)
# Y_train.shape= (86, 15)
# X_val.shape= (776, 256, 256, 3)
# Y_val.shape= (776, 15)

# %% [markdown]
# 七、数据增强，训练

# %%
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(X_train, Y_train,
              batch_size=batch_size,
              epochs=nb_epoch,
              verbose=1,
              validation_data=(X_val, Y_val),
              shuffle=True,
              callbacks=[lr_reducer,checkpointer, early_stopper, csv_logger])
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=True,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=True,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=0, # randomly rotate images in the range (degrees, 0 to 180)
        width_shift_range=False,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=False,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(X_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(X_train, Y_train, batch_size=batch_size),
                        steps_per_epoch=X_train.shape[0] // batch_size,
                        validation_data=(X_val, Y_val),
                        epochs=nb_epoch, verbose=1, max_q_size=100,
                        callbacks=[lr_reducer,checkpointer, early_stopper, csv_logger])
# Out:
# Not using data augmentation.
# Train on 86 samples, validate on 776 samples
# Epoch 1/300
# 86/86 [==============================] - 146s 2s/step - loss: 2.2005 - acc: 0.8256 - val_loss: 16.2904 - val_acc: 0.0696
#
# Epoch 00001: val_loss improved from inf to 16.29040, saving model to imagemodel2.1.h5
# Epoch 2/300
# 86/86 [==============================] - 150s 2s/step - loss: 1.4941 - acc: 0.9302 - val_loss: 1.8759 - val_acc: 0.7461
#
# Epoch 00002: val_loss improved from 16.29040 to 1.87586, saving model to imagemodel2.1.h5
# Epoch 3/300
# 86/86 [==============================] - 157s 2s/step - loss: 1.4090 - acc: 0.9419 - val_loss: 16.2402 - val_acc: 0.0696
#
# Epoch 00003: val_loss did not improve
# Epoch 4/300
# 86/86 [==============================] - 150s 2s/step - loss: 1.3095 - acc: 0.9651 - val_loss: 16.1662 - val_acc: 0.0696
#
# Epoch 00004: val_loss did not improve
# Epoch 5/300
# 86/86 [==============================] - 141s 2s/step - loss: 1.1965 - acc: 1.0000 - val_loss: 2.1924 - val_acc: 0.7680
#
# Epoch 00005: val_loss did not improve
# Epoch 6/300
# 86/86 [==============================] - 141s 2s/step - loss: 1.1246 - acc: 1.0000 - val_loss: 1.6497 - val_acc: 0.9304
#
# Epoch 00006: val_loss improved from 1.87586 to 1.64968, saving model to imagemodel2.1.h5
# Epoch 7/300
# 86/86 [==============================] - 141s 2s/step - loss: 1.0818 - acc: 0.9884 - val_loss: 1.9166 - val_acc: 0.7539
#
# Epoch 00007: val_loss did not improve
# Epoch 8/300
# 86/86 [==============================] - 146s 2s/step - loss: 1.0402 - acc: 0.9884 - val_loss: 3.1115 - val_acc: 0.4923
#
# Epoch 00008: val_loss did not improve
# Epoch 9/300
# 86/86 [==============================] - 150s 2s/step - loss: 1.1035 - acc: 0.9419 - val_loss: 11.9648 - val_acc: 0.0915
#
# Epoch 00009: val_loss did not improve
# Epoch 10/300
# 86/86 [==============================] - 150s 2s/step - loss: 0.9563 - acc: 0.9767 - val_loss: 15.8753 - val_acc: 0.0696
#
# Epoch 00010: val_loss did not improve
# Epoch 11/300
# 86/86 [==============================] - 151s 2s/step - loss: 0.9148 - acc: 0.9767 - val_loss: 15.8371 - val_acc: 0.0696
#
# Epoch 00011: val_loss did not improve
# Epoch 12/300
# 86/86 [==============================] - 150s 2s/step - loss: 0.8525 - acc: 1.0000 - val_loss: 15.7989 - val_acc: 0.0696
#
# Epoch 00012: val_loss did not improve
# Epoch 13/300
# 86/86 [==============================] - 150s 2s/step - loss: 0.8176 - acc: 0.9884 - val_loss: 15.7612 - val_acc: 0.0696
#
# Epoch 00013: val_loss did not improve
# Epoch 14/300
# 86/86 [==============================] - 150s 2s/step - loss: 0.7665 - acc: 1.0000 - val_loss: 2.3329 - val_acc: 0.6160
#
# Epoch 00014: val_loss did not improve
# Epoch 15/300
# 86/86 [==============================] - 149s 2s/step - loss: 0.7386 - acc: 1.0000 - val_loss: 1.1529 - val_acc: 0.8930
#
# Epoch 00015: val_loss improved from 1.64968 to 1.15288, saving model to imagemodel2.1.h5
# Epoch 16/300
# 86/86 [==============================] - 142s 2s/step - loss: 0.7243 - acc: 1.0000 - val_loss: 1.1526 - val_acc: 0.9253
#
# Epoch 00016: val_loss improved from 1.15288 to 1.15257, saving model to imagemodel2.1.h5
# Epoch 17/300
# 86/86 [==============================] - 141s 2s/step - loss: 0.7054 - acc: 1.0000 - val_loss: 1.2162 - val_acc: 0.9278
#
# Epoch 00017: val_loss did not improve
# Epoch 18/300
# 86/86 [==============================] - 141s 2s/step - loss: 0.6963 - acc: 1.0000 - val_loss: 1.3434 - val_acc: 0.9304
#
# Epoch 00018: val_loss did not improve
# Epoch 19/300
# 86/86 [==============================] - 141s 2s/step - loss: 0.6825 - acc: 1.0000 - val_loss: 1.4512 - val_acc: 0.9304
#
# Epoch 00019: val_loss did not improve
# Epoch 20/300
# 86/86 [==============================] - 140s 2s/step - loss: 0.6710 - acc: 1.0000 - val_loss: 1.5234 - val_acc: 0.9304
#
# Epoch 00020: val_loss did not improve
# Epoch 21/300
# 86/86 [==============================] - 140s 2s/step - loss: 0.6603 - acc: 1.0000 - val_loss: 1.5698 - val_acc: 0.9304
#
# Epoch 00021: val_loss did not improve
# Epoch 22/300
# 86/86 [==============================] - 146s 2s/step - loss: 0.6497 - acc: 1.0000 - val_loss: 1.5903 - val_acc: 0.9304
#
# Epoch 00022: val_loss did not improve
# Epoch 23/300
# 86/86 [==============================] - 153s 2s/step - loss: 0.6379 - acc: 1.0000 - val_loss: 1.5891 - val_acc: 0.9304
#
# Epoch 00023: val_loss did not improve
# Epoch 24/300
# 86/86 [==============================] - 156s 2s/step - loss: 0.6266 - acc: 1.0000 - val_loss: 1.5657 - val_acc: 0.9304
#
# Epoch 00024: val_loss did not improve
# Epoch 25/300
# 86/86 [==============================] - 158s 2s/step - loss: 0.6255 - acc: 1.0000 - val_loss: 1.4809 - val_acc: 0.9304
#
# Epoch 00025: val_loss did not improve
# Epoch 26/300
# 86/86 [==============================] - 145s 2s/step - loss: 0.6159 - acc: 1.0000 - val_loss: 1.3324 - val_acc: 0.9304
#
# Epoch 00026: val_loss did not improve
# Epoch 27/300
# 86/86 [==============================] - 144s 2s/step - loss: 0.6124 - acc: 1.0000 - val_loss: 1.2119 - val_acc: 0.9304
#
# Epoch 00027: val_loss did not improve
# Epoch 28/300
# 86/86 [==============================] - 143s 2s/step - loss: 0.6085 - acc: 1.0000 - val_loss: 1.1412 - val_acc: 0.9304
#
# Epoch 00028: val_loss improved from 1.15257 to 1.14118, saving model to imagemodel2.1.h5
# Epoch 29/300
# 86/86 [==============================] - 155s 2s/step - loss: 0.6050 - acc: 1.0000 - val_loss: 1.0956 - val_acc: 0.9304
#
# Epoch 00029: val_loss improved from 1.14118 to 1.09560, saving model to imagemodel2.1.h5
# Epoch 30/300
# 86/86 [==============================] - 158s 2s/step - loss: 0.6015 - acc: 1.0000 - val_loss: 1.0640 - val_acc: 0.9317
#
# Epoch 00030: val_loss improved from 1.09560 to 1.06395, saving model to imagemodel2.1.h5
# Epoch 31/300
# 86/86 [==============================] - 157s 2s/step - loss: 0.5981 - acc: 1.0000 - val_loss: 1.0386 - val_acc: 0.9330
#
# Epoch 00031: val_loss improved from 1.06395 to 1.03855, saving model to imagemodel2.1.h5
# Epoch 32/300
# 86/86 [==============================] - 153s 2s/step - loss: 0.5945 - acc: 1.0000 - val_loss: 1.0188 - val_acc: 0.9330
#
# Epoch 00032: val_loss improved from 1.03855 to 1.01880, saving model to imagemodel2.1.h5
# Epoch 33/300
# 86/86 [==============================] - 150s 2s/step - loss: 0.5917 - acc: 1.0000 - val_loss: 1.0039 - val_acc: 0.9330
#
# Epoch 00033: val_loss improved from 1.01880 to 1.00391, saving model to imagemodel2.1.h5
# Epoch 34/300
# 86/86 [==============================] - 150s 2s/step - loss: 0.5868 - acc: 1.0000 - val_loss: 0.9933 - val_acc: 0.9330
#
# Epoch 00034: val_loss improved from 1.00391 to 0.99326, saving model to imagemodel2.1.h5
# Epoch 35/300
# 80/86 [==========================>...] - ETA: 2s - loss: 0.5834 - acc: 1.0000

# %% [markdown]
# 八、测试

# %%
model = load_model('imagemodel2.1.h5')
pred=model.predict(X_val[:10])
print(pred[:10])
print(Y_val[:10])

# %% [markdown]
# 相比如V1.0版本，这里把resnet18改成了resnet34

# %%
prediction=np.argmax(pred,1)
print(prediction)
print(np.argmax(Y_val,1))
